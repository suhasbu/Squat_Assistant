# %%
# Load Dataset
import pandas as pd
import json
import numpy as np
import os
FILE_PATH = "./data/../data/training/"
FILE_NAME = "log_01copy.json"
# dataDictList is a list of dicts
with open(FILE_PATH+FILE_NAME, 'r') as f:
    dataDictList = json.load(f)

# %% [markdown]
# # Update apex.csv
# MUST RUN ALL CELLS IN HELPER FUNCTIONS BEFORE FUNCTIONAL
#
# Running this cell will update the "apex.csv" with information based in the "training" folder

# %%
# Creates 
apex_df = findAllApex('data/training', update = True)
apex_df
# Out:
# Starting findAllApex
# --------------------
# Good squats: 22
# Bad squats: 4
# --------------------
# File path: data/training/good/log_20.json
# 64 entries
# Entry with apex = 44
# --------------------
# File path: data/training/good/log_16.json
# 97 entries
# Entry with apex = 68
# --------------------
# File path: data/training/good/log_01.json
# 111 entries
# Entry with apex = 88
# --------------------
# File path: data/training/good/log_17.json
# 94 entries
# Entry with apex = 14
# --------------------
# File path: data/training/good/log_21.json
# 136 entries
# Entry with apex = 79
# --------------------
# File path: data/training/good/log_10.json
# 53 entries
# Entry with apex = 34
# --------------------
# File path: data/training/good/log_06.json
# 78 entries
# Entry with apex = 51
# --------------------
# File path: data/training/good/log_07.json
# 75 entries
# Entry with apex = 24
# --------------------
# File path: data/training/good/log_11.json
# 118 entries
# Entry with apex = 51
# --------------------
# File path: data/training/good/log_04.json
# 84 entries
# Entry with apex = 0
# --------------------
# File path: data/training/good/log_12.json
# 91 entries
# Entry with apex = 22
# --------------------
# File path: data/training/good/log_08.json
# 175 entries
# Entry with apex = 13
# --------------------
# File path: data/training/good/log_09.json
# 106 entries
# Entry with apex = 40
# --------------------
# File path: data/training/good/log_13.json
# /Users/franco/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:26: RuntimeWarning: invalid value encountered in true_divide
# 79 entries
# Entry with apex = 71
# --------------------
# File path: data/training/good/log_05.json
# 110 entries
# Entry with apex = 61
# --------------------
# File path: data/training/good/log_18.json
# 123 entries
# Entry with apex = 23
# --------------------
# File path: data/training/good/log_22.json
# 40 entries
# Entry with apex = 3
# --------------------
# File path: data/training/good/log_02.json
# 561 entries
# Entry with apex = 552
# --------------------
# File path: data/training/good/log_14.json
# 80 entries
# Entry with apex = 48
# --------------------
# File path: data/training/good/log_15.json
# 196 entries
# Entry with apex = 102
# --------------------
# File path: data/training/good/log_03.json
# 73 entries
# Entry with apex = 1
# --------------------
# File path: data/training/good/log_19.json
# 20 entries
# Entry with apex = 1
# --------------------
# File path: data/training/bad/log_b04.json
# 106 entries
# Entry with apex = 11
# --------------------
# File path: data/training/bad/log_b03.json
# 128 entries
# Entry with apex = 109
# --------------------
# File path: data/training/bad/log_b02.json
# 82 entries
# Entry with apex = 53
# --------------------
# File path: data/training/bad/log_b01.json
# 409 entries
# Entry with apex = 55
# --------------------
# apex.csv updated
# Finish findAllApex
# Found apexes of all 26 squats
#          nose_x    nose_y  leftShoulder_x  leftShoulder_y  rightShoulder_x  \
# entry
# 0      0.117421  0.308928        0.143789        0.286555         0.142810
# 25        0.036523      0.399215      0.036780     0

# %% [markdown]
# # Helper Functions
#
# Contains 4 functions
# ##### genList - reads json file into dataframe
# ##### scale - normalizes dataframe
# ##### findApex - finds apex coordinate of dataframe
# ##### findAllApex - returns dataframe with all apexes
#
# ## Global Constants

# %%
PARTS =  {"nose" : 0, 
  "leftEye" : 1, 
  "rightEye" : 2, 
  "leftEar" : 3, 
  "rightEar" : 4, 
  "leftShoulder" : 5, 
  "rightShoulder" : 6, 
  "leftElbow" : 7, 
  "rightElbow" : 8, 
  "leftWrist" : 9, 
  "rightWrist" : 10, 
  "leftHip" : 11, 
  "rightHip" : 12, 
  "leftKnee" : 13, 
  "rightKnee" : 14, 
  "leftAnkle" : 15, 
  "rightAnkle" : 16}

requiredParts = ["nose", 
#   "leftEye", 
#   "rightEye", 
#   "leftEar", 
#   "rightEar", 
  "leftShoulder", 
  "rightShoulder", 
#   "leftElbow", 
#   "rightElbow", 
#   "leftWrist", 
#   "rightWrist", 
  "leftHip", 
  "rightHip", 
  "leftKnee", 
  "rightKnee", 
  "leftAnkle", 
  "rightAnkle"
]

IMAGE_X_SIZE = 600
IMAGE_Y_SIZE = 450

# %% [markdown]
# ## Read json file
# genList reads a json file and creates an table of the X and Y coordinates

# %%
def genList(dataDictList, requiredParts, startIndex, stopIndex):
    '''
    @args
    dataDictList - json load
    requiredParts - ["nose", etc.]
    startIndex - relative timestamp to start. 0
    stopIndex - relative timestamp to stop. len(dataDictList)
    @returns
    [#, x], [#, y]
    '''
    dataListX = None
    dataListY = None
    for _frame in range(startIndex, stopIndex):
        if dataListX is None:
            dataListX = [[dataDictList['frame-'+str(_frame)]['keypoints'][PARTS[X]]['position'][0] for X in requiredParts]]
            dataListY = [[dataDictList['frame-'+str(_frame)]['keypoints'][PARTS[X]]['position'][1] for X in requiredParts]]
        else:
            dataListX = dataListX + [[dataDictList['frame-'+str(_frame)]['keypoints'][PARTS[_part]]['position'][0] for _part in requiredParts]]
            dataListY = dataListY + [[dataDictList['frame-'+str(_frame)]['keypoints'][PARTS[_part]]['position'][1] for _part in requiredParts]]
    
    dataListX = np.array(dataListX) # [[x]]
    dataListY = np.array(dataListY) # [[y]]
    newDataListX = np.reshape(dataListX, (-1,len(requiredParts))) 
    newDataListY = np.reshape(dataListY, (-1,len(requiredParts))) #[#instance, (y) for each keypoint]
    print(str(len(newDataListX)) + " entries")
    return newDataListX, newDataListY

# %% [markdown]
# ## Normalization
# Normalizes coordinates for our model

# %%
'''
 This has 2 parts-
 Resize, by identifying and scaling as bounding box, and then (Min-Max) Normalize
 Note: The broadcasting here is element-wise. 
 Sources:
 [1] https://medium.com/tensorflow/move-mirror-an-ai-experiment-with-pose-estimation-in-the-browser-using-tensorflow-js-2f7b769f9b23
 [2] https://raw.githubusercontent.com/paulvollmer/posenet-keypoints-normalization/master/src/index.js
 

''' 

def scale(newDataListX, newDataListY):
    '''
    Assumes dataList of form [#instance, [(x,y) for each keypoint]]
    Possible optim: bounding box wont change much across frames
    '''
    # Bounding Box
    maxX = np.max(newDataListX, axis=1)
    minX = np.min(newDataListX, axis=1)
    maxY = np.max(newDataListY, axis=1)
    minY = np.min(newDataListY, axis=1)
    assert(len(minY)==len(newDataListX))
    l2Data = np.concatenate((newDataListX, newDataListY), axis=1)
    # Reset to Origin and Scale
    for _data in range(0, len(newDataListX)):
        l2Data[_data] = l2Data[_data] / np.linalg.norm(l2Data[_data]) # L2 norm if the need be
    return l2Data[:,:newDataListX.shape[-1]], l2Data[:,newDataListY.shape[-1]:]

# %% [markdown]
# ## Find Apex
# Finds the normalized apex for a json file

# %%
def findApex(xTbl, yTbl):
    minColumnIndex = yTbl['leftHip'].idxmin()
    print("Entry with apex = " + str(minColumnIndex))
    xTblApex = xTbl.iloc[minColumnIndex,:]
    yTblApex = yTbl.iloc[minColumnIndex,:]
    apex = []
    for i in range(len(xTblApex)):
        xTblVal = xTblApex[i]
        yTblVal = yTblApex[i]
        apex.append(xTblVal)
        apex.append(yTblVal)
    return apex

# %% [markdown]
# ## Find All Apexes
# Runs findApex on every json file in training, creating dataframe of all apexes classified based off the folder they're in

# %%
def findAllApex(training_path, update):
    print("Starting findAllApex")
    print("--------------------")
    # Creats index names for final table, each part and each coordinate having separate columns
    columnIndices = []
    for index in requiredParts:
        columnIndices.append(index + "_x")
        columnIndices.append(index + "_y")
    columnIndices.append("good")
        
    #Creates list of paths for json files
    goodJson = []
    for file in os.listdir(training_path + "/good"):
        if file.endswith(".json"):
            goodJson.append(os.path.join(training_path + "/good", file))
    badJson = []
    for file in os.listdir(training_path + "/bad"):
        if file.endswith(".json"):
            badJson.append(os.path.join(training_path + "/bad", file))
    jsonList = [goodJson, badJson]
    
    apexes = []
    type = 1
    print("Good squats: " + str(len(goodJson)))
    print("Bad squats: " + str(len(badJson)))
    print("--------------------")
    for jsonFolder in jsonList:
        for path in jsonFolder:
            print("File path: " + path)
            with open(path, 'r') as f:
                dataDictList = json.load(f)
            newDataListX, newDataListY = genList(dataDictList, requiredParts, 0, len(dataDictList))
            scaledDataX, scaledDataY = scale(newDataListX, newDataListY)
            x_key=pd.DataFrame(scaledDataX)
            y_key=pd.DataFrame(scaledDataY)
            x_key.columns=requiredParts
            y_key.columns=requiredParts
            apex_point = findApex(x_key, y_key)
            apex_point.append(type)
            apexes.append(apex_point)
            print("--------------------")
        type = 0
    apex_df = pd.DataFrame(apexes, columns = columnIndices)
    apex_df.index.name = 'entry'
    if update == True:
        apex_df.to_csv('data/apex.csv')
        print("apex.csv updated")
    print("Finish findAllApex")
    print("Found apexes of all "+ str(len(apex_df)) + " squats")
    return apex_df

# %%
def findInputApex(path):
    print("Starting findInputApex")
    print("--------------------")
    # Creats index names for final table, each part and each coordinate having separate columns
    columnIndices = []
    for index in requiredParts:
        columnIndices.append(index + "_x")
        columnIndices.append(index + "_y")

    apexes = []
    with open(path, 'r') as f:
        dataDictList = json.load(f)
    newDataListX, newDataListY = genList(dataDictList, requiredParts, 0, len(dataDictList))
    scaledDataX, scaledDataY = scale(newDataListX, newDataListY)
    x_key=pd.DataFrame(scaledDataX)
    y_key=pd.DataFrame(scaledDataY)
    x_key.columns=requiredParts
    y_key.columns=requiredParts
    apex_point = findApex(x_key, y_key)
    apexes.append(apex_point)
    apex_df = pd.DataFrame(apexes, columns = columnIndices)
    apex_df.index.name = 'entry'
    return apex_df

# %%
findInputApex(FILE_PATH+FILE_NAME)
# Out:
# Starting findAllApex
# --------------------
# 111 entries
# Entry with apex = 88
#         nose_x    nose_y  leftShoulder_x  leftShoulder_y  rightShoulder_x  \
# entry
# 0      0.04586  0.247471        0.079373        0.257763         0.080869
#
#        rightShoulder_y  leftHip_x  leftHip_y  rightHip_x  rightHip_y  \
# entry
# 0             0.206781   0.186991   0.260724    0.187887    0.213658
#
#        leftKnee_x  leftKnee_y  rightKnee_x  rightKnee_y  leftAnkle_x  \
# entry
# 0        0.277885    0.265366     0.283288     0.209369     0.345451
#
#        leftAnkle_y  rightAnkle_x  rightAnkle_y
# entry
# 0         0.278864      0.353202      0.192719

# %% [markdown]
# # Visualizations

# %%
# Choose if you want to plot X or Y

# %%
index=5
fig=plt.figure(figsize=(10, 15), dpi= 80, facecolor='w', edgecolor='k')
for sub in range(0, 4, 1):
    plt.subplot(4, 3, 3*sub+1)
    plt.plot(newDataListX[:,index], 'ko-')
    plt.title(requiredParts[index])
    plt.ylabel('Actual')
    plt.subplot(4, 3, 3*sub+2)
    plt.plot(scaledDataX[:,index],  'r.-')
    plt.title(requiredParts[index])
    plt.ylabel('ScaledX')
    plt.subplot(4, 3, 3*sub+3)
    plt.plot(scaledDataY[:,index],  'r.-')
    plt.title(requiredParts[index])
    plt.ylabel('ScaledY')
    index = index+1
    
plt.tight_layout()
plt.show()

# %%
# fig=plt.figure(figsize=(10, 15), dpi= 80, facecolor='w', edgecolor='k')
# for sub in range(0, 4, 1):
#     plt.subplot(5, 3, (3*sub+1))
#     plt.plot(newDataListX[:,index], 'ko-')
#     plt.title(requiredParts[index])
#     plt.ylabel('Actual')
#     plt.subplot(5, 3, (3*sub+2))
#     plt.plot(scaledDataX[:,index],  'r.-')
#     plt.title(requiredParts[index])
#     plt.ylabel('ScaledX')
#     plt.subplot(5, 3, (3*sub+3))
#     plt.plot(scaledDataY[:,index],  'r.-')
#     plt.title(requiredParts[index])
#     plt.ylabel('ScaledY')
#     index = index+1
    
# plt.tight_layout()
# plt.show()

# %% [markdown]
# fig=plt.figure(figsize=(5, 5), dpi= 80, facecolor='w', edgecolor='k')
# plt.plot(x_key);

# %%
#apex_df['good']

# %%
# Out:
# Test Accuracy:  0.0

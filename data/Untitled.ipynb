# %%
import numpy as np
from numpy import random
from numpy.random import randn
import matplotlib.pyplot as plt
import pandas as pd

# %%
df=pd.read_json("log2.json")

# %%
key=pd.DataFrame(df.keypoints)

# %%
key
# Out:
#                                              keypoints
# 0    [{'score': 0.9864802360534661, 'part': 'nose',...
# 1    [{'score': 0.990541696548461, 'part': 'nose', ...
# 2    [{'score': 0.988194108009338, 'part': 'nose', ...
# 3    [{'score': 0.986265897750854, 'part': 'nose', ...
# 4    [{'score': 0.9873750209808351, 'part': 'nose',...
# ..                                                 ...
# 196  [{'score': 0.9959421753883361, 'part': 'nose',...
# 197  [{'score': 0.9990127086639401, 'part': 'nose',...
# 198  [{'score': 0.99886405467987, 'part': 'nose', '...
# 199  [{'score': 0.9993853569030761, 'part': 'nose',...
# 200  [{'score': 0.9991635084152221, 'part': 'nose',...
#
# [201 rows x 1 columns]

# %%
keypoints=pd.DataFrame(np.load("squatfar4X.npy"))

# %%
keypoints
# Out:
#             0         1         2         3         4         5         6  \
# 0    0.172694  0.170156  0.174916  0.167726  0.174390  0.157959  0.183233
# 1    0.171099  0.168404  0.174168  0.164848  0.179214  0.157353  0.186526
# 2    0.171097  0.168276  0.174277  0.164516  0.179300  0.157697  0.186945
# 3    0.172257  0.169679  0.175170  0.166578  0.179843  0.158252  0.186334
# 4    0.170763  0.167947  0.174202  0.163876  0.179582  0.157554  0.186101
# ..        ...       ...       ...       ...       ...       ...       ...
# 180  0.172363  0.171172  0.172013  0.165717  0.161630  0.165482  0.156141
# 181  0.172287  0.171201  0.172374  0.165598  0.162300  0.164746  0.157793
# 182  0.174540  0.171068  0.171911  0.165509  0.161947  0.165415  0.157080
# 183  0.171714  0.170912  0.172362  0.165209  0.162933  0.164219  0.159622
# 184  0.174224  0.171025  0.172318  0.164118  0.163389  0.163668  0.160173
#
#             7         8         9        10        11        12        13  \
# ...

# %%
plt.plot(keypoints[0])
